# %% [markdown]
#  We will cover all the basics and advanced techniques to analyze and manipulate tabular data with Pandas

# %% [markdown]
# Import libraries.

# %%
import pandas as pd

# %% [markdown]
# Dataaframes.

# %%
df = pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]], columns=['A','B','C'], index=['X', 'Y', 'Z'])
df.head()
# Out:
#    A  B  C
# X  1  2  3
# Y  4  5  6
# Z  7  8  9

# %%
df.tail(2)
# Out:
#    A  B  C
# Y  4  5  6
# Z  7  8  9

# %%
#see all the headers. 
df.columns
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %%
df.index.to_list()
# Out:
# ['X', 'Y', 'Z']

# %%
# Information about data frame. 

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, X to Z
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      int64
#  1   B       3 non-null      int64
#  2   C       3 non-null      int64
# dtypes: int64(3)
# memory usage: 96.0+ bytes

# %%
#Summary of the data
df.describe()
# Out:
#          A    B    C
# count  3.0  3.0  3.0
# mean   4.0  5.0  6.0
# std    3.0  3.0  3.0
# min    1.0  2.0  3.0
# 25%    2.5  3.5  4.5
# 50%    4.0  5.0  6.0
# 75%    5.5  6.5  7.5
# max    7.0  8.0  9.0

# %%
#find unique values. 

df.nunique()
# Out:
# A    3
# B    3
# C    3
# dtype: int64

# %%
df.shape
# Out:
# (3, 3)

# %% [markdown]
# Loading in Dataframes from files

# %%
Coffee = pd.read_csv('coffee.csv')

# %%
Coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %% [markdown]
# the problem is with the data size.

# %%
Results = pd.read_parquet('results.parquet')

Results.head()
# Out:
#      year    type discipline                     event                     as  \
# 0  1912.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 3  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)  Jean-François Blanchy
# 4  1920.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc             team  place   tied medal
# 0           1  FRA             None   17.0   True  None
# 1           1  FRA   Jean Montariol    NaN  False  None
# 2           1  FRA             None   32.0   True  None
# 3           1  FRA  Jeanne Vaussard    8.0   True  None
# 4           1  FRA  Jacques Brugnon    4.0  False  None

# %%
Olympics = pd.read_csv('results.csv')
Olympics.head()
# Out:
#      year    type discipline                     event                     as  \
# 0  1912.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 3  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)  Jean-François Blanchy
# 4  1920.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc             team  place   tied medal
# 0           1  FRA              NaN   17.0   True   NaN
# 1           1  FRA   Jean Montariol    NaN  False   NaN
# 2           1  FRA              NaN   32.0   True   NaN
# 3           1  FRA  Jeanne Vaussard    8.0   True   NaN
# 4           1  FRA  Jacques Brugnon    4.0  False   NaN

# %%
Bios = pd.read_csv('bios.csv')

Bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %% [markdown]
# Accessing Data With Pandas

# %%
Coffee.head(10)
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35
# 5  Wednesday       Latte          25
# 6   Thursday    Espresso          40
# 7   Thursday       Latte          30
# 8     Friday    Espresso          45
# 9     Friday       Latte          35

# %%
Coffee.tail(7)
# Out:
#          Day Coffee Type  Units Sold
# 7   Thursday       Latte          30
# 8     Friday    Espresso          45
# 9     Friday       Latte          35
# 10  Saturday    Espresso          45
# 11  Saturday       Latte          35
# 12    Sunday    Espresso          45
# 13    Sunday       Latte          35

# %%
Coffee.sample(10)
# Out:
#          Day Coffee Type  Units Sold
# 3    Tuesday       Latte          20
# 12    Sunday    Espresso          45
# 8     Friday    Espresso          45
# 10  Saturday    Espresso          45
# 9     Friday       Latte          35
# 11  Saturday       Latte          35
# 7   Thursday       Latte          30
# 2    Tuesday    Espresso          30
# 6   Thursday    Espresso          40
# 13    Sunday       Latte          35

# %% [markdown]
# Access specific values.
#
# loc & iloc
#
# loc allows to filter by rows and columns.

# %%
Coffee.loc[0:3]
# Out:
#        Day Coffee Type  Units Sold
# 0   Monday    Espresso          25
# 1   Monday       Latte          15
# 2  Tuesday    Espresso          30
# 3  Tuesday       Latte          20

# %%
Coffee.loc[0:4, ["Day", "Units Sold"]]
# Out:
#          Day  Units Sold
# 0     Monday          25
# 1     Monday          15
# 2    Tuesday          30
# 3    Tuesday          20
# 4  Wednesday          35

# %% [markdown]
# iloc is similar but uses index instead of labels

# %%
Coffee.iloc[0:5, [0,2]]
# Out:
#          Day  Units Sold
# 0     Monday          25
# 1     Monday          15
# 2    Tuesday          30
# 3    Tuesday          20
# 4  Wednesday          35

# %%
#access specific columns contents. 

Coffee.index = Coffee['Day']
Coffee.index
# Out:
# Index(['Monday', 'Monday', 'Tuesday', 'Tuesday', 'Wednesday', 'Wednesday',
#        'Thursday', 'Thursday', 'Friday', 'Friday', 'Saturday', 'Saturday',
#        'Sunday', 'Sunday'],
#       dtype='object', name='Day')

# %%
Coffee.head(10)
# Out:
#                  Day Coffee Type  Units Sold
# Day
# Monday        Monday    Espresso          25
# Monday        Monday       Latte          15
# Tuesday      Tuesday    Espresso          30
# Tuesday      Tuesday       Latte          20
# Wednesday  Wednesday    Espresso          35
# Wednesday  Wednesday       Latte          25
# Thursday    Thursday    Espresso          40
# Thursday    Thursday       Latte          30
# Friday        Friday    Espresso          45
# Friday        Friday       Latte          35

# %% [markdown]
# Modifying data using loc and iloc in a dataframe

# %%
Coffee1 = Coffee

Coffee1.head()
# Out:
#                  Day Coffee Type  Units Sold
# Day
# Monday        Monday    Espresso          25
# Monday        Monday       Latte          15
# Tuesday      Tuesday    Espresso          30
# Tuesday      Tuesday       Latte          20
# Wednesday  Wednesday    Espresso          35

# %%
Coffee.loc[1, "Units Sold"] = 10

Coffee.head()
# Out:
#                  Day Coffee Type  Units Sold
# Day
# Monday        Monday    Espresso        25.0
# Monday        Monday       Latte        15.0
# Tuesday      Tuesday    Espresso        30.0
# Tuesday      Tuesday       Latte        20.0
# Wednesday  Wednesday    Espresso        35.0

# %%
Coffee.head()
# Out:
#                  Day Coffee Type  Units Sold
# Day
# Monday        Monday    Espresso        25.0
# Monday        Monday       Latte        15.0
# Tuesday      Tuesday    Espresso        30.0
# Tuesday      Tuesday       Latte        20.0
# Wednesday  Wednesday    Espresso        35.0

# %%
Coffee.at[2, 'Coffee Type']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Anonymous\miniconda3\envs\minimal_ds\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:191, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:234, in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# File index.pyx:242, in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# File index.pyx:134, in pandas._libs.index._unpack_bool_indexer()
#
# KeyError: 2
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 Coffee.at[2, 'Coffee Type']
#
# ...

# %%
Coffee.iat[2, 1]
# Out:
# 'Espresso'

# %%
#Grab columns. 

Coffee.Day
# Out:
# 0        Monday
# 1        Monday
# 2       Tuesday
# 3       Tuesday
# 4     Wednesday
# 5     Wednesday
# 6      Thursday
# 7      Thursday
# 8        Friday
# 9        Friday
# 10     Saturday
# 11     Saturday
# 12       Sunday
# 13       Sunday
# Name: Day, dtype: object

# %%
#grab column 

Coffee['Coffee Type']
# Out:
# 0     Espresso
# 1        Latte
# 2     Espresso
# 3        Latte
# 4     Espresso
# 5        Latte
# 6     Espresso
# 7        Latte
# 8     Espresso
# 9        Latte
# 10    Espresso
# 11       Latte
# 12    Espresso
# 13       Latte
# Name: Coffee Type, dtype: object

# %%
Coffee.iloc[:, [1]]
# Out:
#    Coffee Type
# 0     Espresso
# 1        Latte
# 2     Espresso
# 3        Latte
# 4     Espresso
# 5        Latte
# 6     Espresso
# 7        Latte
# 8     Espresso
# 9        Latte
# 10    Espresso
# 11       Latte
# 12    Espresso
# 13       Latte

# %%
Coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
Coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %% [markdown]
# Sort data

# %%
Coffee.sort_values('Units Sold')
# Out:
#           Day Coffee Type  Units Sold
# 1      Monday       Latte          15
# 3     Tuesday       Latte          20
# 0      Monday    Espresso          25
# 5   Wednesday       Latte          25
# 2     Tuesday    Espresso          30
# 7    Thursday       Latte          30
# 4   Wednesday    Espresso          35
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 6    Thursday    Espresso          40
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45

# %%
Coffee.sort_values('Units Sold', ascending=False)
# Out:
#           Day Coffee Type  Units Sold
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45
# 6    Thursday    Espresso          40
# 4   Wednesday    Espresso          35
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 2     Tuesday    Espresso          30
# 7    Thursday       Latte          30
# 0      Monday    Espresso          25
# 5   Wednesday       Latte          25
# 3     Tuesday       Latte          20
# 1      Monday       Latte          15

# %%
Coffee.sort_values(['Units Sold', 'Coffee Type'], ascending=False)
# Out:
#           Day Coffee Type  Units Sold
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45
# 6    Thursday    Espresso          40
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 4   Wednesday    Espresso          35
# 7    Thursday       Latte          30
# 2     Tuesday    Espresso          30
# 5   Wednesday       Latte          25
# 0      Monday    Espresso          25
# 3     Tuesday       Latte          20
# 1      Monday       Latte          15

# %% [markdown]
# FILTERING DATA

# %%
Bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
Bios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   athlete_id    145500 non-null  int64
#  1   name          145500 non-null  object
#  2   born_date     143693 non-null  object
#  3   born_city     110908 non-null  object
#  4   born_region   110908 non-null  object
#  5   born_country  110908 non-null  object
#  6   NOC           145499 non-null  object
#  7   height_cm     106651 non-null  float64
#  8   weight_kg     102070 non-null  float64
#  9   died_date     33940 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 11.1+ MB

# %%
# LOOK AT THE TALLEST ATHLETE. 
Bios.loc[Bios['height_cm'] > 215, ['name', 'height_cm']]
# Out:
#                          name  height_cm
# 5089       Viktor Pankrashkin      220.0
# 5583     Paulinho Villas Boas      217.0
# 5673           Gunther Behnke      221.0
# 5716                 Uwe Blab      218.0
# 5781           Tommy Burleson      223.0
# 5796            Andy Campbell      218.0
# 6223              Lars Hansen      216.0
# 6270              Hu Zhangbao      216.0
# 6409         Sergey Kovalenko      216.0
# 6420            Jānis Krūmiņš      218.0
# 6504              Luc Longley      220.0
# 6722         Shaquille O'Neal      216.0
# 6937           David Robinson      216.0
# 6978          Arvydas Sabonis      223.0
# 7074           Paulo da Silva      217.0
# 7188       Vladimir Tkachenko      220.0
# 7281         Stojko Vranković      217.0
# 7376      Eurelijus Žukauskas      218.0
# 52608         Aleksey Kazakov      217.0
# 82100           Frédéric Weis      218.0
# 89070                Yao Ming      226.0
# 89075          Roberto Dueñas      221.0
# ...

# %%
Bios[Bios['height_cm'] > 215][['name', 'height_cm']]
# Out:
#                          name  height_cm
# 5089       Viktor Pankrashkin      220.0
# 5583     Paulinho Villas Boas      217.0
# 5673           Gunther Behnke      221.0
# 5716                 Uwe Blab      218.0
# 5781           Tommy Burleson      223.0
# 5796            Andy Campbell      218.0
# 6223              Lars Hansen      216.0
# 6270              Hu Zhangbao      216.0
# 6409         Sergey Kovalenko      216.0
# 6420            Jānis Krūmiņš      218.0
# 6504              Luc Longley      220.0
# 6722         Shaquille O'Neal      216.0
# 6937           David Robinson      216.0
# 6978          Arvydas Sabonis      223.0
# 7074           Paulo da Silva      217.0
# 7188       Vladimir Tkachenko      220.0
# 7281         Stojko Vranković      217.0
# 7376      Eurelijus Žukauskas      218.0
# 52608         Aleksey Kazakov      217.0
# 82100           Frédéric Weis      218.0
# 89070                Yao Ming      226.0
# 89075          Roberto Dueñas      221.0
# ...

# %%
# combine multiple values. 

Bios[(Bios['height_cm'] > 215) & (Bios['born_country'] == 'USA')]
# Out:
#         athlete_id              name   born_date  born_city     born_region  \
# 5781          5804    Tommy Burleson  1952-02-24  Crossnore  North Carolina
# 6722          6755  Shaquille O'Neal  1972-03-06     Newark      New Jersey
# 6937          6972    David Robinson  1965-08-06   Key West         Florida
# 123850      126093    Tyson Chandler  1982-10-02    Hanford      California
#
#        born_country            NOC  height_cm  weight_kg died_date
# 5781            USA  United States      223.0      102.0       NaN
# 6722            USA  United States      216.0      137.0       NaN
# 6937            USA  United States      216.0      107.0       NaN
# 123850          USA  United States      216.0      107.0       NaN

# %% [markdown]
# POWER OF REGEX TO FILTER A DATAFRAME

# %%
# Specific information. 

Bios[Bios['name'].str.contains('Stephen|keith')]
# Out:
#         athlete_id                name   born_date      born_city  \
# 827            831      Stephen Hylton  1964-10-23            NaN
# 1431          1438   Alecia Stephenson  1966-03-12      Vancouver
# 3522          3534      Stephen Wilson  1971-03-30      Edinburgh
# 3665          3677     Stephen Ahialey  1970-01-08          Accra
# 4301          4315       Stephen Okumu  1959-02-28            NaN
# ...            ...                 ...         ...            ...
# 140057      143554     Jagger Stephens  1998-05-12  Agana Heights
# 140381      143889    Stephen Scullion  1988-11-09            NaN
# 143353      146997       Stephen Kissa  1995-12-01      Kapchorwa
# 143976      147634       Stephen Zimba  2001-01-10            NaN
# 144813      148515  Shanwayne Stephens  1990-10-19            NaN
#
#              born_region born_country            NOC  height_cm  weight_kg  \
# 827                  NaN          NaN        Jamaica        NaN        NaN
# ...

# %%
#FINDING ATHLETES BORN IN CITIES THAT START WITH A VOWEL. 

VOWEL_CITIES = Bios[Bios['born_city'].str.contains(r'^[AEIOUaeiou]', na=False)]
VOWEL_CITIES
# Out:
#         athlete_id                     name   born_date       born_city  \
# 5                6        Nicolas Chatelain  1970-01-13          Amiens
# 10              11  Élie, Comte de Lastours  1874-08-12         Orgeval
# 17              18     Jean-Philippe Gatien  1968-10-16            Alès
# 35              36          Étienne Thobois  1967-09-20          Amiens
# 40              41           Julie Bradbury  1967-02-12          Oxford
# ...            ...                      ...         ...             ...
# 145395      149118             Abbey Murphy  2002-04-14  Evergreen Park
# 145398      149121          Grace Zumwinkle  1999-04-23       Excelsior
# 145405      149128             Brian Cooper  1993-11-01       Anchorage
# 145418      149141              Nick Perbix  1998-06-15       Elk River
# 145427      149150            Jared Shumate  1999-03-06         Atlanta
#
#        born_region born_country            NOC  height_cm  weight_kg  \
# ...

# %%
#FIND ATHLETES WITH NAMES THAT CONTAIN EXACTLY TWO VOWELS 

TWO_VOWELS = Bios[Bios['name'].str.contains(r'^[^AEIOUaeiou]*[AEIOUaeiou][^AEIOUaeiou]*[^AEIOUaeiou][AEIOUaeiou]*$', na=False)]
TWO_VOWELS
# Out:
#         athlete_id            name   born_date       born_city  \
# 199            200          Tim He  1962-04-14             NaN
# 281            282      S. M. Hadi  1899-08-12       Hyderabad
# 400            401        Tang Hua  1977-09-06             NaN
# 597            599        Macy Lau  1956-06-27             NaN
# 598            600     Ng Wing Nga  1962-12-13             NaN
# ...            ...             ...         ...             ...
# 144439      148131           Xu Fu  1995-11-02             NaN
# 144491      148183      Tomáš Hyka  1993-03-23  Mladá Boleslav
# 144502      148194  Matěj Stránský  1993-07-11         Ostrava
# 144752      148453      Sára Pónya  1999-05-14       Esztergom
# 145483      149210         Feng He  2004-03-31             NaN
#
#                  born_region born_country                         NOC  \
# 199                      NaN          NaN            Hong Kong, China
# ...

# %%
#FIND ATHLETES WITH NAMES THAT HAVE REPEATED CONSECUTIVE LETTERS(EG. "Aaron", "Emment")

REPEATED_LETTERS = Bios[Bios['name'].str.contains(r'(.)\1', na=False)]
REPEATED_LETTERS
# Out:
# C:\Users\Anonymous\AppData\Local\Temp\ipykernel_5528\3006933789.py:3: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   REPEATED_LETTERS = Bios[Bios['name'].str.contains(r'(.)\1', na=False)]
#         athlete_id                  name   born_date          born_city  \
# 9               10    Guy de la Chapelle  1868-07-16  Farges-Allichamps
# 13              14        Étienne Durand         NaN                NaN
# 17              18  Jean-Philippe Gatien  1968-10-16               Alès
# 20              21         Pierre Hirsch  1900-11-08           Paris Ie
# 28              29       Albert Lippmann         NaN                NaN
# ...            ...                   ...         ...                ...
# 145474      149201     Nadine Hofstetter  1994-10-21             Romoos
# 145488      149215          Shakeel John  2001-07-30         Mount Hope
# ...

# %%
# Find athletes with names ending in 'son' or 'sen' 

SON_SEN_NAMES = Bios[Bios['name'].str.contains(r'son$|sen$', case=False, na=False)]
SON_SEN_NAMES
# Out:
#         athlete_id                name   born_date      born_city  \
# 37              38     Helen Aitchison  1881-12-06     Sunderland
# 92              93         Anne Gibson  1968-10-26       Dumfries
# 107            108      Anders Nielsen  1967-02-24      Cape Town
# 113            114    Julian Robertson  1969-10-09   Peterborough
# 120            121     Chris Wilkinson  1970-01-05    Southampton
# ...            ...                 ...         ...            ...
# 145419      149142      Jake Sanderson  2002-07-08      Whitefish
# 145424      149147  Jonathan Gustafson  1997-03-05        Massena
# 145441      149164        Casey Dawson  2000-08-02      Park City
# 145457      149183      Alix Wilkinson  2000-08-02  Mammoth Lakes
# 145461      149188        Kent Johnson  2002-10-18     Port Moody
#
#              born_region born_country            NOC  height_cm  weight_kg  \
# 37               England          GBR  Great Britain        NaN        NaN
# ...

# %%
# FIND ATHLETES BORN IN  YEAR STARTING WITH '19' 

BORN_19xx = Bios[Bios['born_date'].str.contains(r'^19', na=False)]
BORN_19xx
# Out:
#         athlete_id                   name   born_date           born_city  \
# 1                2         Arnaud Boetsch  1969-04-01              Meulan
# 5                6      Nicolas Chatelain  1970-01-13              Amiens
# 6                7          Patrick Chila  1969-11-27         Ris-Orangis
# 7                8           Henri Cochet  1901-12-14        Villeurbanne
# 14              15            Damien Éloi  1969-07-04                Vire
# ...            ...                    ...         ...                 ...
# 145492      149219  Carlos García-Ordóñez  1927-04-24  La Habana (Havana)
# 145493      149220     Landysh Falyakhova  1998-08-31    Dva Polya Artash
# 145496      149223    Valeriya Merkusheva  1999-09-20     Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08              Kotlas
# 145499      149814          Bill Phillips  1913-07-15        Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
# FIND ATHLETES WITH NAMES THAT DO NOT CONTAIN ANY VOWELS 

NO_VOWELS = Bios[Bios['name'].str.contains(r'^[A]*$')]
NO_VOWELS
# Out:
# Empty DataFrame
# Columns: [athlete_id, name, born_date, born_city, born_region, born_country, NOC, height_cm, weight_kg, died_date]
# Index: []

# %%
Bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
# FIND ATHLETES CONTTAINING A HYPHEN OR APOSTROPHE. 

HYPHEN_APOSTROPHE = Bios[Bios['name'].str.contains(r"[-']", na=False)]
HYPHEN_APOSTROPHE
# Out:
#         athlete_id                    name   born_date           born_city  \
# 0                1   Jean-François Blanchy  1886-12-12            Bordeaux
# 15              16  Adrien Fauchier-Magnan  1873-11-19         Paris VIIIe
# 17              18    Jean-Philippe Gatien  1968-10-16                Alès
# 33              34  Jean-Pierre Samazeuilh  1891-01-17            Bordeaux
# 36              37    Pierre Verdé-Delisle  1877-05-16       Trie-la-Ville
# ...            ...                     ...         ...                 ...
# 145385      149108     Ashley Cain-Gribble  1995-07-22              Dallas
# 145388      149111          Jean-Luc Baker  1993-10-07             Burnley
# 145470      149197            Lee Chae-Eun  2006-04-11                 NaN
# 145490      149217             Sin Ye-Chan  1995-06-13                 NaN
# 145492      149219   Carlos García-Ordóñez  1927-04-24  La Habana (Havana)
#
# ...

# %%
#FIND ATHLETES WITH A BORN_CITY THAT HAS EXACTLY 7 CHARACTERS. 

CITY_SEVEN_CHARS = Bios[Bios['born_city'].str.contains(r'^.{7}$', na=False)]
CITY_SEVEN_CHARS
# Out:
#         athlete_id                     name   born_date born_city  \
# 10              11  Élie, Comte de Lastours  1874-08-12   Orgeval
# 25              26            Henri Leconte  1963-07-04   Lillers
# 41              42            Gillian Clark  1961-09-02   Baghdad
# 47              48               Sara Gomer  1964-05-13   Torquay
# 48              49            Alison Gordon  1962-12-31   Reading
# ...            ...                      ...         ...       ...
# 145446      149169         Corinne Stoddard  2001-08-15   Seattle
# 145454      149180            Anna Hoffmann  2000-03-28   Madison
# 145456      149182          Sophie Sorschag  1998-11-14   Villach
# 145459      149186          Roberts Mamčics  1995-04-06   Liepāja
# 145494      149221            George Wright  1890-07-21   Toronto
#
#           born_region born_country            NOC  height_cm  weight_kg  \
# 10           Yvelines          FRA         France        NaN        NaN
# ...

# %%
# Find athletes containing three or more vowels: 

THREE_OR_MORE_VOWELS = Bios[Bios['name'].str.contains(r'([AEIOUaeiou].*){3,}', na=False)]
THREE_OR_MORE_VOWELS
# Out:
# C:\Users\Anonymous\AppData\Local\Temp\ipykernel_5528\4214198849.py:3: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   THREE_OR_MORE_VOWELS = Bios[Bios['name'].str.contains(r'([AEIOUaeiou].*){3,}', na=False)]
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# ...

# %%
Bios[Bios['born_country'].isin(["USA", "GBR", "RUS"]) & (Bios['name'].str.startswith('Stephen'))]
# Out:
#         athlete_id                   name   born_date           born_city  \
# 3522          3534         Stephen Wilson  1971-03-30           Edinburgh
# 11052        11111          Stephen Kelly  1950-12-20            New York
# 11603        11664        Stephen Bradley  1962-03-26          Middleburg
# 14204        14298        Stephen Farrell  1965-06-18      Stoke-on-Trent
# 18145        18266         Stephen Fields  1879-12-31           Knoxville
# 23545        23727         Stephen Kaplan  1949-12-01            New York
# 23582        23765        Stephen Netburn  1943-07-12            New York
# 23627        23811         Stephen Trevor  1963-09-22           Cleveland
# 33508        33765      Stephen Gawthorpe  1958-07-04            Barnsley
# 34533        34802        Stephen Sowerby  1955-03-14           Harrogate
# 37130        37425           Stephen Peel  1965-12-29           Blackburn
# 37197        37493         Stephen Turner  1964-09-17          Barnstaple
# ...

# %% [markdown]
# ABOVE STEPS ARE A BIT CUMBERSOME AND CLUNKY, YOU CAN USE A QUERY.

# %%
Bios.query("born_country == 'RUS' ")
# Out:
#         athlete_id                       name   born_date         born_city  \
# 158            159               Robert Spies  1891-02-17   Moskva (Moscow)
# 686            689        Ulada Charniauskaya  1966-08-10             Biysk
# 2095          2105          Rita Galinovskaya  1968-04-19             Chita
# 2096          2106     Makhlukhanum Murzayeva  1966-10-04       Makhachkala
# 2097          2107  Yelena Tutachikova-Dostay  1969-03-08        Toora-Khem
# ...            ...                        ...         ...               ...
# 145487      149214          Yekaterina Kosova  1996-04-25   Moskva (Moscow)
# 145493      149220         Landysh Falyakhova  1998-08-31  Dva Polya Artash
# 145495      149222          Polina Luchnikova  2002-01-30             Serov
# 145496      149223        Valeriya Merkusheva  1999-09-20   Moskva (Moscow)
# 145497      149224            Yuliya Smirnova  1998-05-08            Kotlas
#
# ...

# %%
Bios.query("born_country == 'RUS' and born_city == 'Chita'")
# Out:
#         athlete_id                 name   born_date born_city  \
# 2095          2105    Rita Galinovskaya  1968-04-19     Chita
# 82219        82872      Lyudmila Titova  1946-03-26     Chita
# 105671      106726         Dmitry Nosov  1980-04-09     Chita
# 111833      113079  Nataliya Boyarskaya  1983-02-27     Chita
# 129388      132003        Alina Stadnik  1991-01-03     Chita
#
#              born_region born_country                 NOC  height_cm  \
# 2095    Zabaykalsky Kray          RUS  Russian Federation      164.0
# 82219   Zabaykalsky Kray          RUS        Soviet Union      176.0
# 105671  Zabaykalsky Kray          RUS  Russian Federation      176.0
# 111833  Zabaykalsky Kray          RUS  Russian Federation      167.0
# 129388  Zabaykalsky Kray          RUS             Ukraine      165.0
#
#         weight_kg died_date
# 2095         53.0       NaN
# 82219        64.0       NaN
# 105671      175.0       NaN
# 111833       67.0       NaN
# 129388       69.0       NaN

# %% [markdown]
# ADDING/REMOVING COLUMNS

# %%
Coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
#ADD PRICE column

Coffee['Price'] = 4.99

# %%
Coffee.head()
# Out:
#          Day Coffee Type  Units Sold  Price
# 0     Monday    Espresso          25   4.99
# 1     Monday       Latte          15   4.99
# 2    Tuesday    Espresso          30   4.99
# 3    Tuesday       Latte          20   4.99
# 4  Wednesday    Espresso          35   4.99

# %%
# ADD SPECIFIC PRICES TO THE COFFEE TYPE 

import numpy as np 

Coffee['new_price'] = np.where(Coffee['Coffee Type'] == 'Espresso', 3.99, 5.99)

# %%
Coffee.head()
# Out:
#          Day Coffee Type  Units Sold  Price  new_price
# 0     Monday    Espresso          25   4.99       3.99
# 1     Monday       Latte          15   4.99       5.99
# 2    Tuesday    Espresso          30   4.99       3.99
# 3    Tuesday       Latte          20   4.99       5.99
# 4  Wednesday    Espresso          35   4.99       3.99

# %%
#dropping the price column. 

Coffee.drop(columns=['Price'])
# Out:
#           Day Coffee Type  Units Sold  new_price
# 0      Monday    Espresso          25       3.99
# 1      Monday       Latte          15       5.99
# 2     Tuesday    Espresso          30       3.99
# 3     Tuesday       Latte          20       5.99
# 4   Wednesday    Espresso          35       3.99
# 5   Wednesday       Latte          25       5.99
# 6    Thursday    Espresso          40       3.99
# 7    Thursday       Latte          30       5.99
# 8      Friday    Espresso          45       3.99
# 9      Friday       Latte          35       5.99
# 10   Saturday    Espresso          45       3.99
# 11   Saturday       Latte          35       5.99
# 12     Sunday    Espresso          45       3.99
# 13     Sunday       Latte          35       5.99

# %%
Coffee.head()
# Out:
#          Day Coffee Type  Units Sold  Price  new_price
# 0     Monday    Espresso          25   4.99       3.99
# 1     Monday       Latte          15   4.99       5.99
# 2    Tuesday    Espresso          30   4.99       3.99
# 3    Tuesday       Latte          20   4.99       5.99
# 4  Wednesday    Espresso          35   4.99       3.99

# %%
#to modify the original dataset. 

Coffee.drop(columns=['Price'], inplace=True)

# %%
Coffee.head()
# Out:
#          Day Coffee Type  Units Sold  new_price
# 0     Monday    Espresso          25       3.99
# 1     Monday       Latte          15       5.99
# 2    Tuesday    Espresso          30       3.99
# 3    Tuesday       Latte          20       5.99
# 4  Wednesday    Espresso          35       3.99

# %%
Coffee['Revenue'] = Coffee['Units Sold'] * Coffee['new_price']

# %%
Coffee.head()
# Out:
#          Day Coffee Type  Units Sold  new_price  Revenue
# 0     Monday    Espresso          25       3.99    99.75
# 1     Monday       Latte          15       5.99    89.85
# 2    Tuesday    Espresso          30       3.99   119.70
# 3    Tuesday       Latte          20       5.99   119.80
# 4  Wednesday    Espresso          35       3.99   139.65

# %%
#renaming a column 

Coffee = Coffee.rename(columns={'new_price':'Price','Units Sold' :'Units_sold','Coffee Type':'Coffee_type'})

# %%
Coffee
# Out:
#           Day Coffee_type  Units_sold  Price  Revenue
# 0      Monday    Espresso          25   3.99    99.75
# 1      Monday       Latte          15   5.99    89.85
# 2     Tuesday    Espresso          30   3.99   119.70
# 3     Tuesday       Latte          20   5.99   119.80
# 4   Wednesday    Espresso          35   3.99   139.65
# 5   Wednesday       Latte          25   5.99   149.75
# 6    Thursday    Espresso          40   3.99   159.60
# 7    Thursday       Latte          30   5.99   179.70
# 8      Friday    Espresso          45   3.99   179.55
# 9      Friday       Latte          35   5.99   209.65
# 10   Saturday    Espresso          45   3.99   179.55
# 11   Saturday       Latte          35   5.99   209.65
# 12     Sunday    Espresso          45   3.99   179.55
# 13     Sunday       Latte          35   5.99   209.65

# %%
Bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
#get the first name 
BIOS_NEW = Bios.copy()

# %%
BIOS_NEW['first_name'] = BIOS_NEW['name'].str.split(' ').str[0]
BIOS_NEW
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
#add birth year. 

BIOS_NEW.query('first_name == "Stephen"')
# Out:
#         athlete_id              name   born_date  born_city    born_region  \
# 827            831    Stephen Hylton  1964-10-23        NaN            NaN
# 3522          3534    Stephen Wilson  1971-03-30  Edinburgh       Scotland
# 3665          3677   Stephen Ahialey  1970-01-08      Accra  Greater Accra
# 4301          4315     Stephen Okumu  1959-02-28        NaN            NaN
# 9669          9724     Stephen Brown  1956-05-09        NaN            NaN
# ...            ...               ...         ...        ...            ...
# 133437      136376   Stephen Lambdin  1988-03-09   Rockwall          Texas
# 138175      141568      Stephen Maar  1994-12-06        NaN            NaN
# 140381      143889  Stephen Scullion  1988-11-09        NaN            NaN
# 143353      146997     Stephen Kissa  1995-12-01  Kapchorwa        Eastern
# 143976      147634     Stephen Zimba  2001-01-10        NaN            NaN
#
# ...

# %%
#converting to datetime 

BIOS_NEW['born_datetime'] = pd.to_datetime(BIOS_NEW['born_date'])
BIOS_NEW
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
BIOS_NEW.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 12 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   athlete_id     145500 non-null  int64
#  1   name           145500 non-null  object
#  2   born_date      143693 non-null  object
#  3   born_city      110908 non-null  object
#  4   born_region    110908 non-null  object
#  5   born_country   110908 non-null  object
#  6   NOC            145499 non-null  object
#  7   height_cm      106651 non-null  float64
#  8   weight_kg      102070 non-null  float64
#  9   died_date      33940 non-null   object
#  10  first_name     145500 non-null  object
#  11  born_datetime  143693 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), int64(1), object(8)
# memory usage: 13.3+ MB

# %%
BIOS_NEW['born_year'] = BIOS_NEW['born_datetime'].dt.year 

BIOS_NEW[['name', 'born_year']]
# Out:
#                          name  born_year
# 0       Jean-François Blanchy     1886.0
# 1              Arnaud Boetsch     1969.0
# 2                Jean Borotra     1898.0
# 3             Jacques Brugnon     1895.0
# 4                Albert Canet     1878.0
# ...                       ...        ...
# 145495      Polina Luchnikova     2002.0
# 145496    Valeriya Merkusheva     1999.0
# 145497        Yuliya Smirnova     1998.0
# 145498         André Foussard     1899.0
# 145499          Bill Phillips     1913.0
#
# [145500 rows x 2 columns]

# %%
BIOS_NEW['born_leap_year'] = BIOS_NEW['born_datetime'].dt.is_leap_year

BIOS_NEW[['name', 'born_leap_year']]
# Out:
#                          name  born_leap_year
# 0       Jean-François Blanchy           False
# 1              Arnaud Boetsch           False
# 2                Jean Borotra           False
# 3             Jacques Brugnon           False
# 4                Albert Canet           False
# ...                       ...             ...
# 145495      Polina Luchnikova           False
# 145496    Valeriya Merkusheva           False
# 145497        Yuliya Smirnova           False
# 145498         André Foussard           False
# 145499          Bill Phillips           False
#
# [145500 rows x 2 columns]

# %%
#classify athletes into short average and tall. 

Bios['Height_category'] = Bios['height_cm'].apply(lambda x: 'Short' if x < 165
                                                                         else ('Average' if x < 185
                                                                         else 'Tall'))

Bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date Height_category
# 0  1960-10-02            Tall
# 1         NaN         Average
# 2  1994-07-17         Average
# 3  1978-03-20         Average
# 4  1930-07-25            Tall

# %% [markdown]
# MERGING & CONCATENATING DATA

# %%
Bios
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
#COMPARE ATHLETES WHERE THEY WEREC BORN AND WHERE THEY COMPETE FOR. 

nocs = pd.read_csv('noc_regions.csv')
nocs.head()
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %%
BIOS1 = pd.merge(Bios, 
         nocs,
         left_on ="born_country",
         right_on ="NOC", how="left" )

BIOS1.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country   NOC_x  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date Height_category NOC_y  region notes
# 0  1960-10-02            Tall   FRA  France   NaN
# 1         NaN         Average   FRA  France   NaN
# ...

# %%
BIOS1.rename(columns={'region':'born_country_full'}, inplace=True)
BIOS1.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country   NOC_x  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date Height_category NOC_y born_country_full notes
# 0  1960-10-02            Tall   FRA            France   NaN
# 1         NaN         Average   FRA            France   NaN
# ...

# %%
Combine_df = pd.merge(Results, Bios,
                      on='athlete_id', how="left")

Combine_df.head()
# Out:
#      year    type discipline                     event                     as  \
# 0  1912.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 3  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)  Jean-François Blanchy
# 4  1920.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc             team  place   tied  ...                   name  \
# 0           1  FRA             None   17.0   True  ...  Jean-François Blanchy
# 1           1  FRA   Jean Montariol    NaN  False  ...  Jean-François Blanchy
# 2           1  FRA             None   32.0   True  ...  Jean-François Blanchy
# 3           1  FRA  Jeanne Vaussard    8.0   True  ...  Jean-François Blanchy
# 4           1  FRA  Jacques Brugnon    4.0  False  ...  Jean-François Blanchy
#
# ...

# %% [markdown]
# HANDING NULL VALUES

# %%
Coffee.loc[[0,1], 'Unit Sold'] = np.nan
Coffee
# Out:
#           Day Coffee Type  Units Sold  new_price  Unit Sold
# 0      Monday    Espresso          25       3.99        NaN
# 1      Monday       Latte          15       5.99        NaN
# 2     Tuesday    Espresso          30       3.99        NaN
# 3     Tuesday       Latte          20       5.99        NaN
# 4   Wednesday    Espresso          35       3.99        NaN
# 5   Wednesday       Latte          25       5.99        NaN
# 6    Thursday    Espresso          40       3.99        NaN
# 7    Thursday       Latte          30       5.99        NaN
# 8      Friday    Espresso          45       3.99        NaN
# 9      Friday       Latte          35       5.99        NaN
# 10   Saturday    Espresso          45       3.99        NaN
# 11   Saturday       Latte          35       5.99        NaN
# 12     Sunday    Espresso          45       3.99        NaN
# 13     Sunday       Latte          35       5.99        NaN

# %%
Coffee['Revenue'] = Coffee['Units Sold'] * Coffee['new_price']



Coffee.head()
# Out:
#          Day Coffee Type  Units Sold  new_price  Unit Sold  Revenue
# 0     Monday    Espresso          25       3.99        NaN    99.75
# 1     Monday       Latte          15       5.99        NaN    89.85
# 2    Tuesday    Espresso          30       3.99        NaN   119.70
# 3    Tuesday       Latte          20       5.99        NaN   119.80
# 4  Wednesday    Espresso          35       3.99        NaN   139.65

# %%
Coffee.fillna(Coffee['Units Sold'].mean())
# Out:
#           Day Coffee Type  Units Sold  new_price  Unit Sold  Revenue
# 0      Monday    Espresso          25       3.99  32.857143    99.75
# 1      Monday       Latte          15       5.99  32.857143    89.85
# 2     Tuesday    Espresso          30       3.99  32.857143   119.70
# 3     Tuesday       Latte          20       5.99  32.857143   119.80
# 4   Wednesday    Espresso          35       3.99  32.857143   139.65
# 5   Wednesday       Latte          25       5.99  32.857143   149.75
# 6    Thursday    Espresso          40       3.99  32.857143   159.60
# 7    Thursday       Latte          30       5.99  32.857143   179.70
# 8      Friday    Espresso          45       3.99  32.857143   179.55
# 9      Friday       Latte          35       5.99  32.857143   209.65
# 10   Saturday    Espresso          45       3.99  32.857143   179.55
# 11   Saturday       Latte          35       5.99  32.857143   209.65
# 12     Sunday    Espresso          45       3.99  32.857143   179.55
# ...

# %%
Coffee.drop(columns="Unit Sold", inplace=True)

# %%
Coffee.rename(columns={'Units Sold':'Units_sold'}, inplace=True)
Coffee
# Out:
#           Day Coffee Type  Units_sold  new_price  Revenue
# 0      Monday    Espresso          25       3.99    99.75
# 1      Monday       Latte          15       5.99    89.85
# 2     Tuesday    Espresso          30       3.99   119.70
# 3     Tuesday       Latte          20       5.99   119.80
# 4   Wednesday    Espresso          35       3.99   139.65
# 5   Wednesday       Latte          25       5.99   149.75
# 6    Thursday    Espresso          40       3.99   159.60
# 7    Thursday       Latte          30       5.99   179.70
# 8      Friday    Espresso          45       3.99   179.55
# 9      Friday       Latte          35       5.99   209.65
# 10   Saturday    Espresso          45       3.99   179.55
# 11   Saturday       Latte          35       5.99   209.65
# 12     Sunday    Espresso          45       3.99   179.55
# 13     Sunday       Latte          35       5.99   209.65

# %% [markdown]
# AGGREGATE DATA

# %%
Bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date Height_category
# 0  1960-10-02            Tall
# 1         NaN         Average
# 2  1994-07-17         Average
# 3  1978-03-20         Average
# 4  1930-07-25            Tall

# %%
Bios['born_city'].value_counts()
# Out:
# born_city
# Budapest           1378
# Moskva (Moscow)     883
# Oslo                708
# Stockholm           629
# Praha (Prague)      600
#                    ...
# Bodrogkisfalud        1
# Ternberg              1
# Klaus                 1
# Plaški                1
# Dulwich Hill          1
# Name: count, Length: 22368, dtype: int64

# %%
Bios[Bios['born_country'] == 'USA']['born_region'].value_counts()
# Out:
# born_region
# California              1634
# New York                 990
# Illinois                 585
# Pennsylvania             530
# Massachusetts            530
# New Jersey               381
# Texas                    368
# Minnesota                365
# Ohio                     328
# Michigan                 319
# Washington               240
# Florida                  235
# Wisconsin                209
# Colorado                 207
# Connecticut              156
# Indiana                  150
# Oregon                   132
# Georgia                  129
# Virginia                 121
# Maryland                 117
# District of Columbia     107
# Iowa                     102
# Hawaiʻi                   95
# Kansas                    94
# Oklahoma                  93
# Louisiana                 92
# Utah                      91
# Missouri                  91
# North Carolina            86
# Arizona                   83
# New Hampshire             83
# ...

# %%
Coffee.groupby(['Coffee Type']).agg({'Units_sold': 'sum', 'new_price': 'mean'})
# Out:
#              Units_sold  new_price
# Coffee Type
# Espresso            265       3.99
# Latte               195       5.99

# %%
Coffee
# Out:
#                  Day Coffee Type  Units Sold
# Day
# Monday        Monday    Espresso        25.0
# Monday        Monday       Latte        15.0
# Tuesday      Tuesday    Espresso        30.0
# Tuesday      Tuesday       Latte        20.0
# Wednesday  Wednesday    Espresso        35.0
# Wednesday  Wednesday       Latte        25.0
# Thursday    Thursday    Espresso        40.0
# Thursday    Thursday       Latte        30.0
# Friday        Friday    Espresso        45.0
# Friday        Friday       Latte        35.0
# Saturday    Saturday    Espresso        45.0
# Saturday    Saturday       Latte        35.0
# Sunday        Sunday    Espresso        45.0
# Sunday        Sunday       Latte        35.0
# 1                NaN         NaN        10.0

# %%
#pivoting 

pivot = Coffee.pivot(columns='Coffee Type', index='Day', values='Revenue')
pivot
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Anonymous\miniconda3\envs\minimal_ds\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Revenue'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[95], line 3
#       1 #pivoting
# ...

# %%
Bios
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...
